# %%
from data import load_and_engineer
df = load_and_engineer("data/flights_canonical_2019.parquet", models_dir="models")
print(f"Shape: {df.shape}")   # should be ~7M rows × 60-70 cols, NOT 150
# Out:
# [cache] Reading flights_canonical_2019_cache.parquet …
# [cache] 7,268,232 rows · 63 cols ready.
# Shape: (7268232, 63)

# %%
ls -lh data/flights_canonical_2019_cache.parquet
# Out:
# -rw-rw-r-- 1 jon jon 761M Apr 19 06:33 data/flights_canonical_2019_cache.parquet
