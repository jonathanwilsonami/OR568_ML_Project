# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
print(tf.test.is_built_with_cuda())
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775385669.219274   10183 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1775385669.461635   10183 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %% [markdown]
# ## Training on GPU
#
# - Don't install using conda
# - Update drivers nvidia-smi - sudo apt install nvidia-driver-580
# - python -m pip install "tensorflow[and-cuda]"
#
# python3 -c "import tensorflow as tf; print(tf.config.list_physical_devices('GPU'))"
#
# https://www.tensorflow.org/install/pip
# Apply TensorFlow’s official Linux symlink fix
#
# 2000  pushd $(dirname $(python -c 'print(__import__("tensorflow").__file__)'))
#  2001  ln -svf ../nvidia/*/lib/*.so* .
#  2002  popd
#  2003  ln -sf $(find $(dirname $(dirname $(python -c "import nvidia.cuda_nvcc; print(nvidia.cuda_nvcc.__file__)"))/*/bin/) -name ptxas -print -quit) $CONDA_PREFIX/bin/ptxas
#
#
# sudo apt purge '^nvidia-.*' '^libnvidia-.*' '^cuda-.*' '^nsight-.*'
# sudo apt autoremove --purge -y
# sudo apt autoclean
#
# docker build -f docker/Dockerfile.tf-gpu -t or568-tf-gpu .
#
# docker run --rm -it \
#   --gpus all \
#   -p 8888:8888 \
#   -v "$PWD":/workspace \
#   -w /workspace \
#   or568-tf-gpu \
#   jupyter lab --ip=0.0.0.0 --port=8888 --no-browser --allow-root
#
#
# ./docker/run_jupyter_gpu.sh
#
# Runs in ~20min
#
# Nice card! The RTX 3070 Ti is a solid GPU for ML work. Here's what you're working with:
# SpecValueVRAM8GB GDDR6XCUDA Cores6144ArchitectureAmpere (SM 8.6)CUDA Compute8.6
# For your ML workloads:
#
# 8GB VRAM is comfortable for most tabular/sklearn-style work and moderate deep learning
# Handles TensorFlow/PyTorch training well for small-to-mid sized models
# You may hit VRAM limits with large batch sizes or big neural nets — just something to watch
#
# CPU Specs
# PropertyDetailsTotal Installed96 GB (2 × 48 GB)TypeDDR5Form FactorDIMM (Unbuffered)Part NumberF5-6400J3239F48G (G.Skill Trident Z5)Rated Speed5600 MT/sRunning At5200 MT/sVoltage1.1VSlots Used2 of 4 (DIMM 1 on Channel A & B)Max Capacity128 GBECCNone
